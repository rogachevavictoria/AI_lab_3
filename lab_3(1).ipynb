# %%
import matplotlib.pyplot as plt
 
import datetime as dt
import dateutil as du
 
import os
 
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
original_path = '/content/gdrive/My Drive/Colab Notebooks/'

data_dir = os.path.join(original_path, 'data')
data_dir
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %%
opsdGurl = os.path.join(data_dir,'opsd_germany_daily.txt')
opsdGurl
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data/opsd_germany_daily.txt'

# %%
import pandas as pd
df = pd.read_csv(opsdGurl, index_col=0)
print(df)
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
df.describe()
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  2920.000000  2188.000000  2187.000000
# mean   1338.675836   164.814173    89.258695   272.663481
# std     165.775710   143.692732    58.550099   146.319884
# min     842.395000     5.757000     1.968000    21.478000
# 25%    1217.859000    62.353250    35.179250   172.185500
# 50%    1367.123000   119.098000    86.407000   240.991000
# 75%    1457.761000   217.900250   135.071500   338.988000
# max    1709.568000   826.278000   241.580000   851.556000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2+ KB

# %%
df.dropna()
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2012-01-01    948.12800  227.465   6.587     234.052
# 2012-01-02   1269.58100  207.327   6.574     213.901
# 2012-01-03   1334.74500  473.468  24.679     498.147
# 2012-01-04   1347.13600  499.804  14.681     514.485
# 2012-01-05   1376.65800  523.851   5.071     528.922
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [2187 rows x 4 columns]

# %%
print(df.var())
# Out:
# Consumption    27481.586104
# Wind           20647.601139
# Solar           3428.114148
# Wind+Solar     21409.508477
# dtype: float64
